# %%
import pprint 
import pandas as pd
import numpy 
from selenium import webdriver
from selenium.webdriver.common.by import By
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
import re
import string
import time 

ACT_website = 'http://classic.austlii.edu.au/au/legis/act/consol_act/fva2016158/index.html#s115'
NSW_website = 'http://www5.austlii.edu.au/au/legis/nsw/consol_act/capva2007347/'
NT_website = 'http://classic.austlii.edu.au/au/legis/nt/consol_act/dafva2007254/'
QLD_website = 'http://classic.austlii.edu.au/au/legis/qld/consol_act/dafvpa2012379/'
VIC_website = 'http://www5.austlii.edu.au/au/legis/vic/consol_act/fvpa2008283/'

# %%
driver = webdriver.Chrome()
driver.get(NSW_website)
time.sleep(1)
legis = driver.find_elements(By.XPATH,"/html/body/pre/a[@href]")

# %%
for legi in legis:
    prop = legi.get_attribute("href") 
    if prop.endswith(".html"):
        driver.get(prop)
        content = driver.find_element(By.XPATH,"/html/body").text 
        print(content)
        driver.back()
        driver.quit()
# Out:
# New South Wales Consolidated Acts
# [Index] [Table] [Search] [Search this Act] [Notes] [Noteup] [Previous] [Next] [Download] [History] [Help]
# CRIMES (DOMESTIC AND PERSONAL VIOLENCE) ACT 2007 - LONG TITLE
# An Act to protect persons from domestic and personal violence; to repeal Part 15A of the Crimes Act 1900 ; and to make consequential amendments to other Acts and instruments.
#
# AustLII: Copyright Policy | Disclaimers | Privacy Policy | Feedback
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1280         """Send a complete request to the server."""
# -> 1281         self._send_request(method, url, body, headers, encode_chunked)
#    1282
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1326             body = _encode(body, 'body')
# -> 1327         self.endheaders(body, encode_chunked=encode_chunked)
#    1328
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1275             raise CannotSendHeader()
# -> 1276         self._send_output(message_body, encode_chunked=encode_chunked)
#    1277
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/http/client.py in send(self, data)
#     975             if self.auto_open:
# --> 976                 self.connect()
#     977             else:
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     186             raise NewConnectionError(
# --> 187                 self, "Failed to establish a new connection: %s" % e
#     188             )
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fca78d72350>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /var/folders/nk/3yltr5qs0zqfr7s_tw7yjrx00000gn/T/ipykernel_20058/2574588943.py in <module>
#       1 for legi in legis:
# ----> 2     prop = legi.get_attribute("href")
#       3     if prop.endswith(".html"):
#       4         driver.get(prop)
#       5         content = driver.find_element(By.XPATH,"/html/body").text
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in get_attribute(self, name)
#     178             _load_js()
#     179         attribute_value = self.parent.execute_script(
# --> 180             "return (%s).apply(null, arguments);" % getAttribute_js, self, name
#     181         )
#     182         return attribute_value
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     504         command = Command.W3C_EXECUTE_SCRIPT
#     505
# --> 506         return self.execute(command, {"script": script, "args": converted_args})["value"]
#     507
#     508     def execute_async_script(self, script: str, *args):
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     440                 params["sessionId"] = self.session_id
#     441
# --> 442         response = self.command_executor.execute(driver_command, params)
#     443         if response:
#     444             self.error_handler.check_response(response)
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     292         data = utils.dump_json(params)
#     293         url = f"{self._url}{path}"
# --> 294         return self._request(command_info[0], url, body=data)
#     295
#     296     def _request(self, method, url, body=None):
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     314
#     315         if self.keep_alive:
# --> 316             response = self._conn.request(method, url, body=body, headers=headers)
#     317             statuscode = response.status
#     318         else:
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77         else:
#      78             return self.request_encode_body(
# ---> 79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#      81
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     826                 chunked=chunked,
#     827                 body_pos=body_pos,
# --> 828                 **response_kw
#     829             )
#     830
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     826                 chunked=chunked,
#     827                 body_pos=body_pos,
# --> 828                 **response_kw
#     829             )
#     830
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     826                 chunked=chunked,
#     827                 body_pos=body_pos,
# --> 828                 **response_kw
#     829             )
#     830
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
#     787             retries = retries.increment(
# --> 788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789             )
#     790             retries.sleep()
#
# /opt/anaconda3/envs/hit140env/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     590
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#     594         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=53836): Max retries exceeded with url: /session/95f681a9b202ff201a4c526169731240/execute/sync (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fca78d72350>: Failed to establish a new connection: [Errno 61] Connection refused'))
